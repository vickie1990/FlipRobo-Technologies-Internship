# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\hp\appdata\roaming\python\python39\site-packages (4.7.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\appdata\roaming\python\python39\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\appdata\roaming\python\python39\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\hp\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\users\hp\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hp\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\appdata\roaming\python\python39\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# Q.10 Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %%
driver=webdriver.Chrome(r'C:\Users\hp\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get("https://www.hostelworld.com")

# %%
Search=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')
Search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e8ab889173132e6ab3618ec7cca75358", element="16004008-f482-40ff-9e81-de067ed57516")>

# %%
Search.send_keys("London")

# %%
search_btn=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/span/i')
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e8ab889173132e6ab3618ec7cca75358", element="fb648a1a-a056-4bd0-8c31-6b132046fcf3")>

# %%
search_btn.click()

# %%
Go_btn=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[5]/button')
Go_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e8ab889173132e6ab3618ec7cca75358", element="42592e86-6e60-4bd1-b1c4-bd67855371b4")>

# %%
Go_btn.click()

# %%
dist_tags=driver.find_elements(By.XPATH,'//span[@class="description"]')
len(dist_tags)
# Out:
# 30

# %%
distance_from_city_centre=[]
for i in dist_tags:
    distance_from_city_centre.append(i.text)

# %%
dorm_tags=driver.find_elements(By.XPATH,'//div[@class="prices-col"]/a[1]/div[2]')
len(dorm_tags)
# Out:
# 30

# %%
dorms_from_price=[] 
for i in dorm_tags:
    dorms_from_price.append(i.text)
dorms_from_price
# Out:
# ['Dorms From\nRs3900.96 Rs3121',
#  'Dorms From\nRs2945.3 Rs2651',
#  'Dorms From\nRs2225',
#  'Dorms From\nRs2855',
#  'Dorms From\nRs2185',
#  'Dorms From\nRs3015.29 Rs2865',
#  'Dorms From\nRs4279',
#  'Dorms From\nRs2273',
#  'Dorms From\nRs2459.03 Rs2213',
#  'Dorms From\nRs855',
#  'Dorms From\nRs1739.75 Rs1392',
#  'Dorms From\nRs3217',
#  'Dorms From\nRs1057',
#  'Dorms From\nRs1978.01 Rs1780',
#  'Dorms From\nRs4552',
#  'Dorms From\nRs1548',
#  'Dorms From\nRs1673.44 Rs1506',
#  'Dorms From\nRs2124',
#  'No Dorms Available',
#  'Dorms From\nRs1578',
#  'Dorms From\nRs2259',
#  'Dorms From\nRs2529',
#  'No Dorms Available',
#  'Dorms From\nRs2485',
#  'Dorms From\nRs2630',
#  'Dorms From\nRs2326',
#  'Dorms From\nRs1860.39 Rs1674',
#  'Dorms From\nRs1613.51 Rs1452',
#  'Dorms From\nRs1753',
#  'Dorms From\nRs5496']

# %%
private_tags=driver.find_elements(By.XPATH,'//div[@class="prices-col"]/a[1]/div[1]')
len(private_tags)
# Out:
# 30

# %%
privates_from_price=[] 
for i in private_tags:
    privates_from_price.append(i.text)
privates_from_price
# Out:
# ['Privates From\nRs12257.1 Rs9806',
#  'Privates From\nRs10254.22 Rs9229',
#  'No Privates Available',
#  'Privates From\nRs10908',
#  'Privates From\nRs10833',
#  'Privates From\nRs11963.21 Rs11365',
#  'Privates From\nRs14565',
#  'Privates From\nRs15682',
#  'No Privates Available',
#  'No Privates Available',
#  'Privates From\nRs15783.51 Rs11048',
#  'Privates From\nRs10773',
#  'Privates From\nRs2220',
#  'No Privates Available',
#  'No Privates Available',
#  'Privates From\nRs7374',
#  'No Privates Available',
#  'No Privates Available',
#  'Privates From\nRs9419',
#  'No Privates Available',
#  'Privates From\nRs9643',
#  'Privates From\nRs8142',
#  'Privates From\nRs8901',
#  'No Privates Available',
#  'Privates From\nRs7831',
#  'Privates From\nRs11126',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available',
#  'No Privates Available']

# %%
Url=[]
for i in driver.find_elements(By.XPATH,"//h2[@class='title title-6']/a"):
    Url.append(i.get_attribute("href"))

# %%
len(Url)
# Out:
# 30

# %%
Url
# Out:
# ['https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-City-Hostel-London/London/88047?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Astor-Hyde-Park/London/25678?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Hostel-One-Notting-Hill/London/291433?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany-Hostel-London/London/303427?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Russell-Square-Hostel/London/29412?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Camden/London/505?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Seven-Sisters/London/91108?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/NX-London-Hostel/London/15204?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Kensington-Holland-Park/London/93920?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/No-8-Willesden-Hostel-London/London/18420?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Hyde-Park-Inn-Hostel/London/517?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Destinations-Hostels-The-Gallery/London/314563?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/London-Backpackers/London/527?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Hammersmith/London/20976?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Dover-Castle-Hostel-and-Bar/London/530?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Smart-Hyde-Park-View-Hostel/London/8069?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Queen-Elizabeth-Chelsea/London/50443?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Astor-Victoria/London/524?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Barmy-Badger-Backpackers/London/64746?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/International-Students-House/London/515?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Prime-Backpackers-Angel/London/93902?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Saint-James-Backpackers/London/70909?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Astor-Kensington/London/523?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Shepherds-Bush/London/506?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Greenwich/London/501?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Kensal-Green-Backpackers/London/4483?from=2022-12-19&to=2022-12-22&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/PubLove-The-Steam-Engine-Waterloo/London/29389?from=2022-12-19&to=2022-12-22&guests=2']

# %%
hostel_name=[]
ratings=[]
total_reviews=[] 
overall_reviews=[] 
facilities=[] 
property_description=[]

# %%
for i in Url:
    driver.get(i)
    time.sleep(10)
    
    try:
        name=driver.find_element(By.XPATH,'//div[@class="title-2"]')
        hostel_name.append(name.text.replace("/n","new line"))
    except:
        hostel_name.append('-')
        
    try:
        name=driver.find_element(By.XPATH,'//div[@class="score orange big"]')
        ratings.append(name.text.replace("/n","new line"))
    except:
        ratings.append('-')
    
    try:
        name=driver.find_element(By.XPATH,'//div[@class="reviews"]')
        total_reviews.append(name.text.replace("/n","new line"))
    except:
        total_reviews.append('-')
       
    try:
        name=driver.find_element(By.XPATH,'//div[@class="keyword"]/span')
        overall_reviews.append(name.text.replace("/n","new line"))
    except:
        overall_reviews.append('-')    

    try:
        name=driver.find_element(By.XPATH,'//ul[@class="facility-sections"]')
        facilities.append(name.text.replace("/n","new line"))
    except:
        facilities.append('-')  
        
    try:
        name=driver.find_element(By.XPATH,'//div[@class="content collapse-content"]')
        property_description.append(name.text.replace("/n","new line"))
    except:
        property_description.append('-')

# %%
len(hostel_name),len(distance_from_city_centre),len(ratings),len(total_reviews),len(overall_reviews),len(privates_from_price),len(dorms_from_price),len(facilities),len(property_description)
# Out:
# (30, 30, 30, 30, 30, 30, 30, 30, 30)

# %%
Hostels=pd.DataFrame()
Hostels['hostel_name']= hostel_name
Hostels['distance_from_city_centre']= distance_from_city_centre
Hostels['ratings']= ratings
Hostels['total_reviews']= total_reviews
Hostels['overall_reviews']= overall_reviews
Hostels['privates_from_price']= privates_from_price
Hostels['dorms_from_price']= dorms_from_price
Hostels['facilities']= facilities
Hostels['property_description']= property_description
        
Hostels
# Out:
#                                 hostel_name         distance_from_city_centre  \
# 0               Wombat's City Hostel London   Hostel - 3.6km from city centre
# 1                  St Christopher's Village   Hostel - 1.8km from city centre
# 2                           Astor Hyde Park   Hostel - 4.3km from city centre
# 3                   Hostel One Notting Hill   Hostel - 5.5km from city centre
# 4                          Generator London     Hostel - 3km from city centre
# 5                      Urbany Hostel London   Hostel - 5.4km from city centre
# 6         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 7               Smart Russell Square Hostel   Hostel - 2.6km from city centre
# 8                   St Christopher's Camden   Hostel - 4.3km from city centre
# 9                        No.8 Seven Sisters     Hostel - 9km from city centre
# 10                         NX London Hostel   Hostel - 6.1km from city centre
# 11  Safestay London Kensington Holland Park   Hostel - 5.9km from city centre
# 12             No.8 Willesden Hostel London    Hostel - 10km from city centre
# 13               Smart Hyde Park Inn Hostel     Hostel - 5km from city centre
# 14       Destinations Hostels @ The Gallery   Hostel - 1.7km from city centre
# 15                       London Backpackers  Hostel - 11.9km from city centre
# 16             St Christopher's Hammersmith   Hostel - 7.5km from city centre
# 17              Dover Castle Hostel and Bar   Hostel - 1.7km from city centre
# 18              Smart Hyde Park View Hostel     Hostel - 5km from city centre
# 19                  Queen Elizabeth Chelsea   Hostel - 5.7km from city centre
# 20                           Astor Victoria   Hostel - 1.8km from city centre
# 21                 Barmy Badger Backpackers   Hostel - 5.5km from city centre
# 22             International Students House   Hostel - 3.3km from city centre
# 23                  Prime Backpackers Angel   Hostel - 3.6km from city centre
# 24                  Saint James Backpackers   Hostel - 5.5km from city centre
# 25                         Astor Kensington   Hostel - 4.9km from city centre
# 26          St Christopher's Shepherds Bush     Hostel - 7km from city centre
# 27               St Christopher's Greenwich   Hostel - 7.6km from city centre
# 28                 Kensal Green Backpackers   Hostel - 8.2km from city centre
# 29     PubLove @ The Steam Engine, Waterloo   Hostel - 0.5km from city centre
#
#    ratings        total_reviews overall_reviews  \
# 0      8.9  14409 Total Reviews        Fabulous
# 1      8.0  11760 Total Reviews        Fabulous
# 2      8.7  11810 Total Reviews        Fabulous
# 3      9.3   1631 Total Reviews          Superb
# 4      7.7   7290 Total Reviews       Very Good
# 5      9.2    570 Total Reviews          Superb
# 6      7.2   4727 Total Reviews       Very Good
# 7      7.1   9845 Total Reviews       Very Good
# 8      8.2   3927 Total Reviews        Fabulous
# 9        -   3925 Total Reviews          Rating
# 10     7.6   1409 Total Reviews       Very Good
# 11     6.9   1395 Total Reviews            Good
# 12     6.8   4912 Total Reviews            Good
